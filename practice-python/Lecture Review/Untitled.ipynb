# %%
names = ['raymond', 'rachel', 'matthew']
colors = ['red', 'green', 'blue', 'yellow']
for name, color in zip(names, colors):
    print(name, '--->', color)

# %%
blocks = []

while True:
    block = f.read(32)
    if block == '':
        break
    blocks.append(block)

# %%
import sys

def solve(a0, a1, a2, b0, b1, b2):
    alice_score = 0
    bob_score = 0
    for i in range(2):
        if "a" + str(i)) > int("b" + str(i)):
            alice_score += 1
            print("alice_score_called")
            print(int("a" + str(i)))
            print(int("b" + str(i)))
            print(alice_score)
        elif int('a' + str(i)) < int("b" + str(i)):
            bob_score += 1
            print("bob_score_called")
            print(int("a" + str(i)))
            print(int("b" + str(i)))
            print(alice_score)
    return [alice_score, bob_score]
            
    
a0, a1, a2 = map(lambda x: int(x), input().strip().split(' '))
b0, b1, b2 = map(lambda x: int(x), input().strip().split(' '))
result = solve(a0, a1, a2, b0, b1, b2)

# %%
import sys

n,k = [int(x) for x in input().strip().split(' ')]
x = sorted([int(x_temp) for x_temp in input().strip().split(' ')])
prev_x, max_x = min(x), max(x)
transmitter_loc = []
for i in range(n - 1):
    if transmitter_loc and x[i] - transmitter_loc[-1] <= k:
        continue
    if (x[i + 1] - x[i]) > k:
        transmitter_loc.append(x[i])
    elif (x[i + 1] - x[i]) == k:
        transmitter_loc.append(x[i + 1])
    else:
        
        
print(len(transmitter_loc))
# Out:
# 5 1
# 1 2 3 4 5
# 2
# 5
# 2

# %%
# Out:
#           #
#         # #
#       # # #
#     # # # #
#   # # # # #
# # # # # # #

# %%
#!/bin/python3

import sys

def timeConversion(s):
    #if 1~11AM OR 12PM
    if((s[-2:] == "AM"and int(s[:2]) < 12) or (s[-2:] == "PM" and s[:2] == "12")):
        return s[:-2]
    #if 12AM or 1~11PM
    elif((s[-2:] == "AM" and s[:2] == "12") or (s[-2:] == "PM" and int(s[:2]) < 12)):
        return str(int(s[:2]) + 12) + s[2:-2]

s = input().strip()
result = timeConversion(s)
print(result)
# Out:
# 12:05:39AM
# 24:05:39

# %%
N = int(input())

# Get the array 
numArray1 = list(map(int, input().split()))
numArray2 = list(map(int, input().split()))

sumArray = []
sumArray = [numArray1[i] + numArray2[i] for i in range(N)]
sumArray
# Out:
# 1
# 1 2
# 1 2
# [2]

# %%
import sys
from fractions import gcd
from functools import reduce

def lcm(a,b):
    return a * b // gcd(a, b)

def lcm_list(n):
    return reduce(lambda x,y: lcm(x, y), n)

def gcd_list(n):
    return reduce(lambda x,y: gcd(x, y), n)
    
def getTotalX(a, b):
    # n is common divisor of b and common multiple of a
    # find least common multiple of a: 
    gcd_b = gcd_list(b)
    lcm_a = lcm_list(a)
    return ([x for x in range(lcm_a, gcd_b + 1, lcm_a) if gcd_b % x == 0])
    
getTotalX([2, 4], [16, 32, 96])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:12: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
#   if sys.path[0] == '':
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: fractions.gcd() is deprecated. Use math.gcd() instead.
# [4, 8, 16]
