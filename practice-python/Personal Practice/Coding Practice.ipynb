# %%
def pos_neg(a, b, negative):
  #return T when neg = F, if a= neg b = pos, or a = pos b = neg
  #return T when neg = T, if a = neg b = neg 
  if negative:
    return ((a and not b) or (not a and b))
  elif not negative:
    return (not a and not b)

pos_neg(1, -1, False)
# Out:
# False

# %%
def not_string(str):
  string_not = 'not'
  index = str.find(string_not, 0, len(str))
  print (index)

not_string('not bad')
# Out:
# 0

# %%
def front_back(str):
    if len(str) > 1:
        first_ch = str[0]
        last_ch = str[len(str)-1]
        new_str = last_ch + str[1:len(str)-1] + first_ch
        return new_str
    else:
        return str

front_back('code')
# Out:
# 'eodc'

# %%
from functools import reduce
def array_count9(nums):
    f = reduce(lambda count, a: count + 1 if a == 9 else count, nums)
    return f
array_count9([9])
# Out:
# 9

# %%
def string_match(a, b):
  length = 0
  if len(a) < len(b):
    length = len(a)
  else:
    length = len(b)
  
  counter = 0
  
  for i in range(0, length):
    if a[i : i + 1] == b[i : i + 1]:
        print (a[i: i + 2], b[i: i + 2])
        counter += 1
  return counter
string_match('xxcaazz', 'xxbaaz')
# Out:
# xx xx
# xc xb
# aa aa
# az az
# zz z
# 5

# %%
def same_first_last(nums):
  first_element = nums[0]
  last_element = nums[len(nums) - 1]
  return len(nums) > 1 and first_element == last_element
same_first_last([])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-ba8fedc0bc1e> in <module>()
#       3   last_element = nums[len(nums) - 1]
#       4   return len(nums) > 1 and first_element == last_element
# ----> 5 same_first_last([])
#       6
#
# <ipython-input-78-ba8fedc0bc1e> in same_first_last(nums)
#       1 def same_first_last(nums):
# ----> 2   first_element = nums[0]
#       3   last_element = nums[len(nums) - 1]
#       4   return len(nums) > 1 and first_element == last_element
#       5 same_first_last([])
#
# IndexError: list index out of range

# %%
def make_bricks(small, big, goal):
  if big != 0:
    goal_div_five = goal // 5
    if goal_div_five > 0 and goal_div_five < big:
     goal = goal - 5 * goal_div_five
    elif goal_div_five > 0 and goal_div_five >= big:
        goal = goal - 5 * big
    else:
        pass
  return goal - small <= 0



make_bricks(3, 2, 9)
# Out:
#   File "<ipython-input-85-9aa5b89200de>", line 4
#     if goal_div_five > 0 and goal_div_five < big
#                                                  ^
# SyntaxError: invalid syntax

# %%
def last2(str):
  last_two = str[len(str) - 3:]
  print (last_two)

last2('xaxaxaxx')
# Out:
# axx
